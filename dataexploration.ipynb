# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_asia.csv")
df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate
# 0        41128771.0         20362329.0       20766442.0         NaN  \
# 1        40099462.0         19844584.0       20254878.0      35.842
# 2        38972230.0         19279930.0       19692301.0      36.051
# 3        37769499.0         18679089.0       19090409.0      36.466
# 4        36686784.0         18136922.0       18549862.0      36.927
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)
# 0         NaN                        9.0                        NaN  \
# 1       7.344                        9.0                        NaN
# 2       7.113                        9.0                   18.48131
# 3       6.791                        9.0                   18.33941
# 4       6.981                        9.0                   18.12015
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)
# 0                           NaN                                  NaN  \
# 1                           NaN                                  NaN
# 2                      45.98341                             53.91368
# 3                      44.51263                             59.36147
# 4                      44.39712                             63.66947
#
#    Female Employment in Industry(%)  ...  Renewable Energy Consumption (%)
# 0                               NaN  ...                               NaN  \
# 1                               NaN  ...                             17.86
# 2                          26.41834  ...                             17.58
# 3                          24.07933  ...                             18.51
# 4                          23.55313  ...                             17.96
#
#    Fossil Fuel Consumption (%)  Male life expectancy  Female life expectancy
# 0                          NaN                   NaN                      NaN  \
# 1                          NaN                58.915                   65.279
# 2                          NaN                59.866                   65.432
# 3                          NaN                60.619                   66.677
# 4                          NaN                59.923                   66.458
#
#    School enrollment, primary  School enrollment, tertiary
# 0                         NaN                          NaN  \
# 1                         NaN                          NaN
# 2                         NaN                     10.85844
# 3                  110.007507                          NaN
# 4                  107.780533                      9.96379
#
#    Primary completion rate  Literacy rate  Year      Country
# 0                      NaN            NaN  2022  Afghanistan
# 1                      NaN      55.929401  2021  Afghanistan
# 2                      NaN            NaN  2020  Afghanistan
# 3                86.175522            NaN  2019  Afghanistan
# 4                88.735519            NaN  2018  Afghanistan
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Making your own question 01? (1.5 points)
#
# **A possible question is :** How does the gender distribution vary by continent?
#
#
# **Answering this question will:** show the differences in male and female populations across continents.
#
# **How we answer this question:** Calculate the average male and female populations for each continent.

# %% [markdown]
# ### Analyzing to get the answer

# %%
year = 2022
data_for_fixed_year = df[df['Year'] == year]
# Group the data by continent and calculate the average male and female populations
average_gender_distribution = data_for_fixed_year.groupby('Country')[['Male Population', 'Female Population']].median().round(1)

# Display the result
print(average_gender_distribution)

plt.figure(figsize=(12, 10))
average_gender_distribution.plot(kind='line', stacked=True)
plt.title('Average Gender Distribution by Country in 2022')  # Đặt tiêu đề của biểu đồ
plt.xlabel('Country')  # Đặt nhãn trục x
plt.ylabel('Population')  # Đặt nhãn trục y
plt.legend(["Male Population", "Female Population"])  # Hiển thị chú thích
plt.show()
# Out:
#                            Male Population  Female Population
# Country
# Afghanistan                     20766442.0         20362329.0
# Armenia                          1250079.0          1530390.0
# Azerbaijan                       5020523.0          5154492.0
# Bahrain                           912199.0           560034.0
# Bangladesh                      84859213.0         86327159.0
# Bhutan                            413930.0           368525.0
# Brunei Darussalam                 232205.0           216797.0
# Cambodia                         8299527.0          8468316.0
# China                          720646499.0        691528501.0
# Cyprus                            626775.0           624713.0
# Georgia                          1745015.0          1967488.0
# India                          731180498.0        685992675.0
# Indonesia                      138703277.0        136798063.0
# Iran, Islamic Rep.              44714592.0         43835978.0
# Iraq                            22290370.0         22205751.0
# Israel                           4763616.0          4786984.0
# Japan                           60810077.0         64314912.0
# Jordan                           5846915.0          5438953.0
# Kazakhstan                       9442885.0         10179087.0
# Korea, Dem. People’s Rep.       12905119.0         13164298.0
# Korea, Rep.                     25773753.0         25854364.0
# Kuwait                           2595948.0          1672926.0
# Kyrgyz Republic                  3340302.0          3462998.0
# Lao PDR                          3794678.0          3734796.0
# Lebanon                          2662356.0          2827383.0
# Malaysia                        17341833.0         16596389.0
# Maldives                          301315.0           222471.0
# Mongolia                         1685387.0          1712979.0
# Myanmar                         26962566.0         27216740.0
# Nepal                           14646246.0         15901334.0
# Oman                             2785494.0          1790804.0
# Pakistan                       118960880.0        116863982.0
# Philippines                     58679278.0         56879731.0
# Qatar                            1954233.0           740889.0
# Russian Federation              66670833.0         76884903.0
# Saudi Arabia                    20979233.0         15429586.0
# Singapore                        2947974.0          2689047.0
# Sri Lanka                       10682766.0         11498234.0
# Syrian Arab Republic            11078628.0         11046621.0
# Tajikistan                       5008732.0          4944055.0
# Thailand                        34806096.0         36890933.0
# Turkey                          42762429.0         42578812.0
# Turkmenistan                     3185860.0          3244911.0
# United Arab Emirates             6547744.0          2893385.0
# Uzbekistan                      17838536.0         17809564.0
# Vietnam                         48501287.0         49685569.0
# Yemen, Rep.                     17023203.0         16673411.0

# %% [markdown]
# ## Making your own question 02? (1.5 points)
#
# **A possible question is :** Is there a correlation between a country's GDP and its birth rate growth in 2020?
#
# **Answering this question will:** help us understand the relationship between economic development and population growth.
#
# **How we answer this question:** Calculate the correlation between GDP and population growth for each country in 2020.

# %%
year = 2020
data_for_fixed_year = df[df['Year'] == year]
# Calculate the correlation between GDP and population growth for each country
correlation_data = data_for_fixed_year.groupby('Country')[['GDP in USD', 'Birth Rate']].mean().round(1)
correlation_data
# Out:
#                              GDP in USD  Birth Rate
# Country
# Afghanistan                2.014345e+10        36.1
# Armenia                    1.264170e+10        12.5
# Azerbaijan                 4.269300e+10        12.5
# Bahrain                    3.462181e+10        12.6
# Bangladesh                 3.739022e+11        18.1
# Bhutan                     2.325186e+09        12.6
# Brunei Darussalam          1.200580e+10        14.2
# Cambodia                   2.587280e+10        19.8
# China                      1.468774e+13         8.5
# Cyprus                     2.500827e+10        10.6
# Georgia                    1.584292e+10        13.0
# India                      2.671595e+12        16.6
# Indonesia                  1.059055e+12        16.6
# Iran, Islamic Rep.         2.397355e+11        14.2
# Iraq                       1.809241e+11        27.7
# Israel                     4.132677e+11        19.2
# Japan                      5.048790e+12         6.8
# Jordan                     4.357992e+10        22.3
# Kazakhstan                 1.710824e+11        22.8
# Korea, Dem. People’s Rep.           NaN        13.3
# Korea, Rep.                1.644313e+12         5.3
# Kuwait                     1.059488e+11        11.8
# Kyrgyz Republic            7.780873e+09        24.0
# Lao PDR                    1.898180e+10        22.4
# Lebanon                    3.171213e+10        15.3
# Malaysia                   3.373395e+11        15.4
# Maldives                   3.746329e+09        14.6
# Mongolia                   1.331298e+10        22.4
# Myanmar                    7.893026e+10        17.4
# Nepal                      3.343366e+10        20.6
# Oman                       7.590940e+10        18.8
# Pakistan                   3.004256e+11        28.0
# Philippines                3.617511e+11        22.0
# Qatar                      1.444114e+11        10.9
# Russian Federation         1.493076e+12         9.8
# Saudi Arabia               7.342712e+11        18.2
# Singapore                  3.483922e+11         8.5
# Sri Lanka                  8.444054e+10        14.2
# Syrian Arab Republic       1.115927e+10        19.7
# Tajikistan                 8.133964e+09        27.5
# Thailand                   5.004573e+11         9.2
# Turkey                     7.202888e+11        15.0
# Turkmenistan               4.561057e+10        22.3
# United Arab Emirates       3.494730e+11        10.6
# Uzbekistan                 6.022470e+10        24.6
# Vietnam                    3.466158e+11        15.4
# Yemen, Rep.                         NaN        31.3

# %% [markdown]
# ## Making your own question 03? (1.5 points)
#
# **A possible question is :** How does the gender distribution life expectancy by continent in 2020?
#
#
# **Answering this question will:** show the differences in male and life expectancy across continents.
#
# **How we answer this question:** Calculate the average male and female life expectancy for each continent.

# %%
data_for_fixed_year = df[df['Year'] == year]
# Group the data by continent and calculate the average male and female populations
average_gender_distribution = data_for_fixed_year.groupby('Country')[['Male life expectancy', 'Female life expectancy ']].mean().round(1)

# Display the result
print(average_gender_distribution)

plt.figure(figsize=(12, 10))
average_gender_distribution.plot(kind='bar', stacked=True)
plt.title('Average Gender Distribution by Country in 2022')  # Đặt tiêu đề của biểu đồ
plt.xlabel('Country')  # Đặt nhãn trục x
plt.ylabel('Population')  # Đặt nhãn trục y
plt.legend(["Male Population", "Female Population"])  # Hiển thị chú thích
plt.show()
# Out:
#                            Male life expectancy  Female life expectancy
# Country
# Afghanistan                                59.9                     65.4
# Armenia                                    67.1                     77.0
# Azerbaijan                                 63.0                     71.0
# Bahrain                                    78.2                     80.4
# Bangladesh                                 70.2                     74.0
# Bhutan                                     70.0                     73.5
# Brunei Darussalam                          72.7                     77.0
# Cambodia                                   68.0                     72.7
# China                                      75.3                     81.1
# Cyprus                                     79.3                     83.4
# Georgia                                    67.7                     77.9
# India                                      68.6                     71.8
# Indonesia                                  66.7                     71.0
# Iran, Islamic Rep.                         72.1                     77.8
# Iraq                                       67.0                     71.2
# Israel                                     80.6                     84.8
# Japan                                      81.6                     87.7
# Jordan                                     73.0                     77.8
# Kazakhstan                                 67.1                     75.5
# Korea, Dem. People’s Rep.                  70.8                     75.7
# Korea, Rep.                                80.5                     86.5
# Kuwait                                     75.4                     80.0
# Kyrgyz Republic                            67.8                     76.0
# Lao PDR                                    66.5                     70.6
# Lebanon                                    75.6                     79.9
# Malaysia                                   73.6                     78.5
# Maldives                                   78.8                     81.3
# Mongolia                                   67.5                     77.0
# Myanmar                                    63.8                     70.0
# Nepal                                      67.3                     71.2
# Oman                                       73.3                     76.8
# Pakistan                                   63.9                     68.8
# Philippines                                70.2                     74.0
# Qatar                                      78.2                     80.7
# Russian Federation                         66.5                     76.4
# Saudi Arabia                               75.0                     78.0
# Singapore                                  83.1                     85.9
# Sri Lanka                                  72.6                     80.1
# Syrian Arab Republic                       68.9                     75.6
# Tajikistan                                 66.0                     70.2
# Thailand                                   75.0                     83.7
# Turkey                                     72.8                     79.1
# Turkmenistan                               65.4                     72.0
# United Arab Emirates                       77.5                     81.1
# Uzbekistan                                 67.9                     72.8
# Vietnam                                    70.8                     79.9
# Yemen, Rep.                                61.6                     67.9

# %% [markdown]
# ## Making your own question 04? (1.5 points)
#
# **A possible question is :** What is top 5 country have the average percentage of students who complete primary school in each country?
#
# **Answering this question will:** Show the top 5 averages of Primary completion rate for each continents.
#
# **How we answer this question:** Calculate the average Primary completion rate for each continent.

# %%
avg_Primary_completion_rate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_Primary_completion_rate_df["Avg.Primary completion rate"] = df.groupby("Country")["Primary completion rate"].mean()

# Set the index as a column - countries
avg_Primary_completion_rate_df["Country"] = avg_Primary_completion_rate_df.index

# Drop the index
avg_Primary_completion_rate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_Primary_completion_rate_df.sort_values("Avg.Primary completion rate", inplace=True, ascending=False)

# Display
avg_Primary_completion_rate_df.head()
# Out:
#     Avg.Primary completion rate       Country
# 42                   109.053139  Turkmenistan
# 16                   106.328373         Japan
# 10                   102.607251       Georgia
# 26                   102.517827      Maldives
# 45                   102.214230       Vietnam

# %% [markdown]
# ## Making your own question 05? (1.5 points)
#
# **A possible question is :** What is top 5 country have the average highest unemployment rate ?
#
#
# **Answering this question will:** Show the top 5 countries with the highest average unemployment rate
#
# **How we answer this question:** Calculate the average unemployment rate for 5 continents.

# %%
avg_Unemployment_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_Unemployment_df["Avg.Unemployment rate"] = df.groupby("Country")["Unemployment(%)"].mean()

# Set the index as a column - countries
avg_Unemployment_df["Country"] = avg_Unemployment_df.index

# Drop the index
avg_Unemployment_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_Unemployment_df.sort_values("Avg.Unemployment rate", inplace=True, ascending=False)

# Display
avg_Unemployment_df.head()
# Out:
#     Avg.Unemployment rate             Country
# 17              14.601536              Jordan
# 10              14.276750             Georgia
# 46              12.364821         Yemen, Rep.
# 13              11.263286  Iran, Islamic Rep.
# 39              11.052964          Tajikistan
